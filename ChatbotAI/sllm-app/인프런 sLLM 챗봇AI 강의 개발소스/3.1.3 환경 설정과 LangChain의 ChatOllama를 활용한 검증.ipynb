# %% [markdown]
# # 1. 패키지 설치

# %%
pip install langchain-ollama
# Out:
# Collecting langchain-ollama
#   Downloading langchain_ollama-0.3.7-py3-none-any.whl (24 kB)
# Collecting ollama<1.0.0,>=0.5.3
#   Downloading ollama-0.5.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.74 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from langchain-ollama) (0.3.75)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-ollama) (2.11.7)
# Requirement already satisfied: langsmith>=0.3.45 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-ollama) (0.4.27)
# Requirement already satisfied: PyYAML>=5.3 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-ollama) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-ollama) (25.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-ollama) (1.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-ollama) (9.1.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-ollama) (4.15.0)
# Requirement already satisfied: httpx>=0.27 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from ollama<1.0.0,>=0.5.3->langchain-ollama) (0.28.1)
# Requirement already satisfied: certifi in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from httpx>=0.27->ollama<1.0.0,>=0.5.3->langchain-ollama) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from httpx>=0.27->ollama<1.0.0,>=0.5.3->langchain-ollama) (1.0.9)
# Requirement already satisfied: idna in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from httpx>=0.27->ollama<1.0.0,>=0.5.3->langchain-ollama) (3.10)
# Requirement already satisfied: anyio in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from httpx>=0.27->ollama<1.0.0,>=0.5.3->langchain-ollama) (4.10.0)
# Requirement already satisfied: h11>=0.16 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27->ollama<1.0.0,>=0.5.3->langchain-ollama) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.74->langchain-ollama) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-ollama) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-ollama) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-ollama) (0.24.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.74->langchain-ollama) (0.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.74->langchain-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.74->langchain-ollama) (2.33.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-ollama) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-ollama) (3.4.3)
# Requirement already satisfied: sniffio>=1.1 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from anyio->httpx>=0.27->ollama<1.0.0,>=0.5.3->langchain-ollama) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from anyio->httpx>=0.27->ollama<1.0.0,>=0.5.3->langchain-ollama) (1.3.0)
# Installing collected packages: ollama, langchain-ollama
# Successfully installed langchain-ollama-0.3.7 ollama-0.5.3
#
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -q python-dotenv langchain-community
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -qU langchain-ollama
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U ollama
# Out:
# Requirement already satisfied: ollama in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (0.5.3)
# Requirement already satisfied: httpx>=0.27 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from ollama) (2.11.7)
# Requirement already satisfied: certifi in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from httpx>=0.27->ollama) (2025.8.3)
# Requirement already satisfied: anyio in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from httpx>=0.27->ollama) (4.10.0)
# Requirement already satisfied: idna in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from httpx>=0.27->ollama) (3.10)
# Requirement already satisfied: httpcore==1.* in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (0.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from anyio->httpx>=0.27->ollama) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/sielain/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages (from anyio->httpx>=0.27->ollama) (1.3.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. LLM 답변 생성
#
# - `ChatOllama` 를 활용한 LLM 답변 생성
# - 터미널에서 `ollama pull gemma2` 와 같이 원하는 모델을 가져와야 실행 가능

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="llama3.1",
    temperature=0,
    # other params...
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~/.pyenv/versions/3.10.18/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[31], line 8
#       1 messages = [
#       2     (
#       3         "system",
#    (...)
#       6     ("human", "I love programming."),
#       7 ]
# ----> 8 ai_msg = llm.invoke(messages)
#       9 ai_msg
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:393, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     381 @override
#     382 def invoke(
#     383     self,
#    (...)
#     388     **kwargs: Any,
#     389 ) -> BaseMessage:
#     390     config = ensure_config(config)
#     391     return cast(
#     392         "ChatGeneration",
# --> 393         self.generate_prompt(
#     394             [self._convert_input(input)],
#     395             stop=stop,
#     396             callbacks=config.get("callbacks"),
#     397             tags=config.get("tags"),
#     398             metadata=config.get("metadata"),
#     399             run_name=config.get("run_name"),
#     400             run_id=config.pop("run_id", None),
#     401             **kwargs,
#     402         ).generations[0][0],
#     403     ).message
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1019, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1010 @override
#    1011 def generate_prompt(
#    1012     self,
#    (...)
#    1016     **kwargs: Any,
#    1017 ) -> LLMResult:
#    1018     prompt_messages = [p.to_messages() for p in prompts]
# -> 1019     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:837, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     834 for i, m in enumerate(input_messages):
#     835     try:
#     836         results.append(
# --> 837             self._generate_with_cache(
#     838                 m,
#     839                 stop=stop,
#     840                 run_manager=run_managers[i] if run_managers else None,
#     841                 **kwargs,
#     842             )
#     843         )
#     844     except BaseException as e:
#     845         if run_managers:
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1085, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1083     result = generate_from_stream(iter(chunks))
#    1084 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1085     result = self._generate(
#    1086         messages, stop=stop, run_manager=run_manager, **kwargs
#    1087     )
#    1088 else:
#    1089     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_ollama/chat_models.py:822, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     815 def _generate(
#     816     self,
#     817     messages: list[BaseMessage],
#    (...)
#     820     **kwargs: Any,
#     821 ) -> ChatResult:
# --> 822     final_chunk = self._chat_stream_with_aggregation(
#     823         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     824     )
#     825     generation_info = final_chunk.generation_info
#     826     chat_generation = ChatGeneration(
#     827         message=AIMessage(
#     828             content=final_chunk.text,
#    (...)
#     833         generation_info=generation_info,
#     834     )
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_ollama/chat_models.py:757, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     748 def _chat_stream_with_aggregation(
#     749     self,
#     750     messages: list[BaseMessage],
#    (...)
#     754     **kwargs: Any,
#     755 ) -> ChatGenerationChunk:
#     756     final_chunk = None
# --> 757     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     758         if final_chunk is None:
#     759             final_chunk = chunk
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_ollama/chat_models.py:844, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#     837 def _iterate_over_stream(
#     838     self,
#     839     messages: list[BaseMessage],
#     840     stop: Optional[list[str]] = None,
#     841     **kwargs: Any,
#     842 ) -> Iterator[ChatGenerationChunk]:
#     843     reasoning = kwargs.get("reasoning", self.reasoning)
# --> 844     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     845         if not isinstance(stream_resp, str):
#     846             content = (
#     847                 stream_resp["message"]["content"]
#     848                 if "message" in stream_resp and "content" in stream_resp["message"]
#     849                 else ""
#     850             )
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_ollama/chat_models.py:743, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     741 if chat_params["stream"]:
#     742     if self._client:
# --> 743         yield from self._client.chat(**chat_params)
#     744 else:
#     745     if self._client:
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/ollama/_client.py:165, in Client._request.<locals>.inner()
#     164 def inner():
# --> 165   with self._client.stream(*args, **kwargs) as r:
#     166     try:
#     167       r.raise_for_status()
#
# File ~/.pyenv/versions/3.10.18/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_client.py:868, in Client.stream(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     845 """
#     846 Alternative to `httpx.request()` that streams the response body
#     847 instead of loading it into memory at once.
#    (...)
#     853 [0]: /quickstart#streaming-responses
#     854 """
#     855 request = self.build_request(
#     856     method=method,
#     857     url=url,
#    (...)
#     866     extensions=extensions,
#     867 )
# --> 868 response = self.send(
#     869     request=request,
#     870     auth=auth,
#     871     follow_redirects=follow_redirects,
#     872     stream=True,
#     873 )
#     874 try:
#     875     yield response
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     235 import httpcore
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.10.18/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     151     value = typ()
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#     158     return exc is not value
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     115     raise
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 61] Connection refused

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~/.pyenv/versions/3.10.18/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:393, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     381 @override
#     382 def invoke(
#     383     self,
#    (...)
#     388     **kwargs: Any,
#     389 ) -> BaseMessage:
#     390     config = ensure_config(config)
#     391     return cast(
#     392         "ChatGeneration",
# --> 393         self.generate_prompt(
#     394             [self._convert_input(input)],
#     395             stop=stop,
#     396             callbacks=config.get("callbacks"),
#     397             tags=config.get("tags"),
#     398             metadata=config.get("metadata"),
#     399             run_name=config.get("run_name"),
#     400             run_id=config.pop("run_id", None),
#     401             **kwargs,
#     402         ).generations[0][0],
#     403     ).message
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1019, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1010 @override
#    1011 def generate_prompt(
#    1012     self,
#    (...)
#    1016     **kwargs: Any,
#    1017 ) -> LLMResult:
#    1018     prompt_messages = [p.to_messages() for p in prompts]
# -> 1019     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:837, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     834 for i, m in enumerate(input_messages):
#     835     try:
#     836         results.append(
# --> 837             self._generate_with_cache(
#     838                 m,
#     839                 stop=stop,
#     840                 run_manager=run_managers[i] if run_managers else None,
#     841                 **kwargs,
#     842             )
#     843         )
#     844     except BaseException as e:
#     845         if run_managers:
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1085, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1083     result = generate_from_stream(iter(chunks))
#    1084 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1085     result = self._generate(
#    1086         messages, stop=stop, run_manager=run_manager, **kwargs
#    1087     )
#    1088 else:
#    1089     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_ollama/chat_models.py:822, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     815 def _generate(
#     816     self,
#     817     messages: list[BaseMessage],
#    (...)
#     820     **kwargs: Any,
#     821 ) -> ChatResult:
# --> 822     final_chunk = self._chat_stream_with_aggregation(
#     823         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     824     )
#     825     generation_info = final_chunk.generation_info
#     826     chat_generation = ChatGeneration(
#     827         message=AIMessage(
#     828             content=final_chunk.text,
#    (...)
#     833         generation_info=generation_info,
#     834     )
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_ollama/chat_models.py:757, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     748 def _chat_stream_with_aggregation(
#     749     self,
#     750     messages: list[BaseMessage],
#    (...)
#     754     **kwargs: Any,
#     755 ) -> ChatGenerationChunk:
#     756     final_chunk = None
# --> 757     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     758         if final_chunk is None:
#     759             final_chunk = chunk
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_ollama/chat_models.py:844, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#     837 def _iterate_over_stream(
#     838     self,
#     839     messages: list[BaseMessage],
#     840     stop: Optional[list[str]] = None,
#     841     **kwargs: Any,
#     842 ) -> Iterator[ChatGenerationChunk]:
#     843     reasoning = kwargs.get("reasoning", self.reasoning)
# --> 844     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     845         if not isinstance(stream_resp, str):
#     846             content = (
#     847                 stream_resp["message"]["content"]
#     848                 if "message" in stream_resp and "content" in stream_resp["message"]
#     849                 else ""
#     850             )
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/langchain_ollama/chat_models.py:743, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     741 if chat_params["stream"]:
#     742     if self._client:
# --> 743         yield from self._client.chat(**chat_params)
#     744 else:
#     745     if self._client:
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/ollama/_client.py:165, in Client._request.<locals>.inner()
#     164 def inner():
# --> 165   with self._client.stream(*args, **kwargs) as r:
#     166     try:
#     167       r.raise_for_status()
#
# File ~/.pyenv/versions/3.10.18/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_client.py:868, in Client.stream(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     845 """
#     846 Alternative to `httpx.request()` that streams the response body
#     847 instead of loading it into memory at once.
#    (...)
#     853 [0]: /quickstart#streaming-responses
#     854 """
#     855 request = self.build_request(
#     856     method=method,
#     857     url=url,
#    (...)
#     866     extensions=extensions,
#     867 )
# --> 868 response = self.send(
#     869     request=request,
#     870     auth=auth,
#     871     follow_redirects=follow_redirects,
#     872     stream=True,
#     873 )
#     874 try:
#     875     yield response
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     235 import httpcore
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.10.18/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     151     value = typ()
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#     158     return exc is not value
#
# File ~/.pyenv/versions/3.10.18/envs/sllm-app/lib/python3.10/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     115     raise
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 61] Connection refused

# %%
ai_message.content
# Out:
# '인프런에는 엄청나게 다양한 강의들이 있습니다!  어떤 분야에 관심이 있는지 알려주시면, 더 자세하고 도움이 되는 답변을 드릴 수 있어요. 😄\n\n예를 들어:\n\n* **IT & 개발:** 프로그래밍 (Python, Java, JavaScript 등), 웹개발, 데이터 분석, 클라우드 컴퓨팅\n* **디자인:** UI/UX 디자인, 그래픽 디자인, 일러스트레이션, 비주얼 효과\n* **비즈니스 & 마케팅:** 사업 계획, 디지털 마케팅, 콘텐츠 마케팅, 리더십\n* **취업 & 경력 개발:** 이력서 작성, 면접 준비, 네트워킹, 인턴십\n\n  ... 등등이 있습니다. \n\n혹시 특정 분야나 강의 이름을 알고 계신가요?  🔍'
