# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install -q python-dotenv langchain-upstage
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. 환경변수 불러오기
#
# - `.env` 파일에 `OPENAI_API_KEY` 등록

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # 3. LLM 답변 생성
#
# - Upstage Console에서 발급받은 API Key를 `UPSTAGE_API_KEY`라고 저장하면 별도의 설정 없이 `ChatUpstage`를 사용할 수 있음

# %%
from langchain_upstage import ChatUpstage

llm = ChatUpstage()

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")

# %%
ai_message.content
# Out:
# '인프런에는 다양한 분야의 강의가 있습니다. 주요 카테고리는 다음과 같습니다:\n\n1. **프로그래밍**: 웹 개발, 모바일 앱 개발, 알고리즘, 데이터 구조, 인공지능, 머신러닝 등 다양한 프로그래밍 언어와 기술이 포함되어 있습니다.\n\n2. **IT 엔지니어링**: 네트워크, 시스템 관리, 클라우드 컴퓨팅, DevOps, 인프라 엔지니어링 등 IT 관련 기술에 대한 강의가 있습니다.\n\n3. **디자인**: 웹 디자인, UI/UX 디자인, 그래픽 디자인, 브랜드 디자인 등 디자인 관련 분야가 포함되어 있습니다.\n\n4. **비즈니스**: 마케팅, 경영, 재무, 인사 등 비즈니스 관련 주제의 강의가 있습니다.\n\n5. **생활/취미**: 요리, 사진, 음악, 피트니스 등 다양한 생활 및 취미 관련 강의가 있습니다.\n\n6. **자격증**: 다양한 자격증 준비를 위한 강의가 제공됩니다.\n\n이 외에도 많은 주제의 강의가 있으니, 인프런 웹사이트를 방문하여 더 자세한 정보를 확인해보세요!'
